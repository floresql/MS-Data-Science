# %% [markdown]
# # Week 1 Lab: Introduction and Some Basics

# %% [markdown]
# <img align="left" style="padding-right:20px;" src="figures_wk1/getting_started.png" width=200><br>
#
# This week's lab is primarily to get your Python set up and start getting comfortable with Jupyter notebooks - a tool that is quickly becoming the de facto standard in Data Science. If you've never used Jupyter notebooks, many great tutorials exist online, your instructor can provide links on request.

# %% [markdown]
# # Assignment Requirements

# %% [markdown]
# This week's lab has two or (potentially) three parts, depending on your Python installation:
# 1) If you do not have Anaconda Python installed, do so and make sure your  computer is set up to use it as your default Python.<br><br>
# 2) Re-create **ALL**the manipulations in lecture material Chapter 1 section using the gapminder.tsv data file.
#     - Dataset: The gapminder.tsv data set is located in the data_wk1 folder.
#     <br><br>
# 3) Download your own data set from the [UCI Machine Learning archive](https://archive.ics.uci.edu/ml/index.php) and perform a similar set of manipulations as done on the "gapminder" data.
#     - Jupyter notebooks are so popular because you can have markdown cells that document your process.
#     - **Document Your Steps As You Go** using markdown cells.

# %% [markdown]
# # Deliverables

# %% [markdown]
# Upload your Jupyter Notebook to the corresponding location in WorldClass. I will also need a copy of the dataset the your use for step 3 above.
#
# **Note::** Make sure you have clearly indicated each assignment requirement within your notebook. Also, I <u><i><b>highly encourage</b></i></u> you to use markdown text to create a notebook that integrates text with your code.
